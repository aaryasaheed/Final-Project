# %% [markdown]
# # EVOLUTION OF KPOP ACCROSS GENERATIONS

# %% [markdown]
# Analyze the popularity and characteristics of different kpop artists
#
# Gain insights into the musical characteristics, popularity trends and release patterns of KPOP groups from different generations
#
# Conclusion: what contributes to the success of kpop artists

# %% [markdown]
# ## IMPORTS

# %%
import spotipy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error, silhouette_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## CREDENTIALS

# %%
#MY IDs
secret_id = '3355bc26beee4e998623b9b9817e6245'
my_id = 'a44e325b50154f278abc68994957c7ad'

# %%
#CREDENTIALS
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id= my_id, client_secret= secret_id)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## TOP 10 SONGS BY ARTISTS FROM SECOND, THIRD AND FOURTH GENERATION IN KPOP RANKED BY POPULARITY

# %%
artist_names = ['Girls Generation', 'SHINEE', 'Super Junior', 'Apink', 'BTS', 'SEVENTEEN', 'TWICE', 'EXO', 'NEWJEANS', 'LE SSERAFIM', 'ENHYPEN', 'ATEEZ']

track_results = []
features_df = pd.DataFrame()

for artist_name in artist_names:
    artists = sp.search(q='artist:' + artist_name, type='artist', limit=10)
    artist_uri = artists['artists']['items'][0]['uri']

    results = sp.artist_top_tracks(artist_uri)

    for i, item in enumerate(results['tracks']):
        track_id = item['id']
        track_name = item['name']
        popularity = item['popularity']
        
        artist = sp.artist(artist_uri)
        
        genres = artist['genres']
        
        track_results.append((artist_name, track_name, track_id, item['album']['release_date'], popularity, genres))

        audio_features = sp.audio_features(track_id)
        local_features = pd.DataFrame(audio_features)
        features_df = pd.concat([features_df, local_features], ignore_index=True)

track_df = pd.DataFrame(track_results, columns=('Artist', 'Song Name', 'Id', 'Release Date', 'Popularity', 'Genres'))

final_df = pd.concat([track_df, features_df], axis=1)

# Separate artists into three DataFrames
secondgen = final_df[final_df['Artist'].isin(['Girls Generation', 'SHINEE', 'Super Junior', 'Apink'])]
thirdgen = final_df[final_df['Artist'].isin(['BTS', 'SEVENTEEN', 'TWICE', 'EXO'])]
fourthgen = final_df[final_df['Artist'].isin(['NEWJEANS', 'LE SSERAFIM', 'ENHYPEN', 'ATEEZ'])]

# Sort by popularity
secondgen2 = secondgen.sort_values(by='Popularity', ascending=False)
thirdgen2 = thirdgen.sort_values(by='Popularity', ascending=False)
fourthgen2 = fourthgen.sort_values(by='Popularity', ascending=False)

# %%
secondgen2
df.to_csv('file_name.csv')
# Out:
#               Artist                 Song Name                      Id  \
# 10            SHINEE                      HARD  2VV1RIhTgeJ4PEMYz6TqDB
# 0   Girls Generation                 FOREVER 1  1oen3GpTcA486fTHaT7neg
# 11            SHINEE                    Replay  1rp986nzkyAX1wFpxzbwlC
# 1   Girls Generation                       Gee  0t7kjpVLgOYITrSfFCoBEA
# 13            SHINEE                     JUICE  2ka8U0A2e93hBFA43mbgfy
# 12            SHINEE            Ring Ding Dong  4vLqN0bIxIQjlet2mIMBnx
# 2   Girls Generation        Into the New World  1RTW9UthqmZwr8Od6CH4i8
# 14            SHINEE                      View  46E1ic6n099e76t5J1TbHn
# 2    2007-11-01          65  [k-pop, k-pop girl group]         0.708   0.892
# 14   2015-05-18          65   [k-pop, k-pop boy group]         0.728   0.801
# 15   2021-02-22          64   [k-pop, k-pop boy group]         0.690   0.783
# 20   2009-03-11          64   [k-pop, k-pop boy group]         0.706   0.972
# 4    2015-08-19          64  [k-pop, k-pop girl group]         0.754   0.788
# 30   2014-03-31          63  [k-pop, k-pop girl group]         0.769   0.837
# 16   2023-06-26          63   [k-pop, k-pop boy group]         0.728   0.727
# 17   2023-06-26          63   [k-pop, k-pop boy group]         0.638   0.931
# 18   2023-06-26          63   [k-pop, k-pop boy group]         0.485   0.858
# 19   2023-06-26          63   [k-pop, k-pop boy group]         0.772   0.880
# 3    2011-10-19          62  [k-pop, k-pop girl group]         0.885   0.937
# 6    2013-01-01          62  [k-pop, k-pop girl group]         0.502   0.863
# 21   2011-08-02          61   [k-pop, k-pop boy group]         0.913   0.745
# 8    2010-03-22          60  [k-pop, k-pop girl group]         0.687   0.888
# 31   2020-04-13          60  [k-pop, k-pop girl group]         0.653   0.923
# 32   2018-07-02          59  [k-pop, k-pop girl group]         0.594   0.810
# 9    2014-02-24          59  [k-pop, k-pop girl group]         0.701   0.964
# 33   2013-07-05          58  [k-pop, k-pop girl group]         0.740   0.908
# 23   2018-04-12          57   [k-pop, k-pop boy group]         0.746   0.738
# 34   2023-04-05          57  [k-pop, k-pop girl group]         0.789   0.799
# 7    2010-01-28          57  [k-pop, k-pop girl group]         0.759   0.966
# 22   2017-11-06          56   [k-pop, k-pop boy group]         0.711   0.885
# 24   2014-08-29          56   [k-pop, k-pop boy group]         0.716   0.928
# 5    2010-01-28          56  [k-pop, k-pop girl group]         0.762   0.840
# 35   2019-01-07          56  [k-pop, k-pop girl group]         0.647   0.855
# 36   2022-02-14          54  [k-pop, k-pop girl group]         0.647   0.845
# 25   2010-05-13          54   [k-pop, k-pop boy group]         0.790   0.911
# 28   2009-05-14          54   [k-pop, k-pop boy group]         0.752   0.934
# 27   2010-06-25          54   [k-pop, k-pop boy group]         0.643   0.924
# 26   2015-07-16          54   [k-pop, k-pop boy group]         0.773   0.865
# 37   2014-11-24          53  [k-pop, k-pop girl group]         0.735   0.911
# 29   2018-10-08          51   [k-pop, k-pop boy group]         0.685   0.841
# 38   2011-04-19          49  [k-pop, k-pop girl group]         0.627   0.841
# 39   2011-11-22          48  [k-pop, k-pop girl group]         0.680   0.949
#
#     key  loudness  ...  liveness  valence    tempo            type  \
# 10    2    -3.002  ...    0.0347    0.687   91.969  audio_features
# 0     9    -1.248  ...    0.2540    0.297  123.915  audio_features
# 11    1    -2.203  ...    0.1670    0.590   99.977  audio_features
# 1     1    -1.082  ...    0.1100    0.737   99.988  audio_features
# 13   10    -2.183  ...    0.0449    0.761  170.049  audio_features
# 12    1    -1.258  ...    0.2220    0.811  124.980  audio_features
# 2     4    -1.964  ...    0.1140    0.623  108.031  audio_features
# 14    6    -4.428  ...    0.0415    0.656  123.953  audio_features
# 15    2    -2.076  ...    0.0962    0.306   82.026  audio_features
# 20   11    -2.359  ...    0.2670    0.962  129.946  audio_features
# 4     2    -3.175  ...    0.0775    0.961  124.992  audio_features
# 30    2    -3.499  ...    0.2380    0.584  120.005  audio_features
# 16   11    -3.608  ...    0.0486    0.597  101.974  audio_features
# 17    1    -2.370  ...    0.1750    0.484  116.165  audio_features
# 18    6    -3.848  ...    0.0953    0.460  172.015  audio_features
# 19    1    -4.574  ...    0.1450    0.686  107.029  audio_features
# 3     1    -0.678  ...    0.1030    0.878  114.974  audio_features
# 6     4    -1.273  ...    0.5380    0.527   97.911  audio_features
# 21    1    -2.837  ...    0.0622    0.795  127.996  audio_features
# 8    11    -2.725  ...    0.1810    0.791   64.927  audio_features
# 31    8    -2.163  ...    0.1370    0.692  114.902  audio_features
# 32    6    -2.083  ...    0.0324    0.777  123.752  audio_features
# 9     4    -2.037  ...    0.1530    0.484  113.058  audio_features
# 33    4    -2.668  ...    0.0637    0.745  105.996  audio_features
# 23    9    -3.670  ...    0.0430    0.630   94.808  audio_features
# 34   10    -1.560  ...    0.1290    0.765  111.961  audio_features
# 7     2    -2.207  ...    0.2290    0.440  143.987  audio_features
# 22    5    -3.299  ...    0.2070    0.866  121.978  audio_features
# 24    7    -0.005  ...    0.0702    0.697  101.564  audio_features
# 5     9    -2.603  ...    0.7140    0.719  123.006  audio_features
# 35    5    -2.944  ...    0.1370    0.683  144.867  audio_features
# 36    5    -4.084  ...    0.1080    0.432  130.040  audio_features
# 25   11    -1.756  ...    0.1010    0.876  125.012  audio_features
# 28    7    -3.541  ...    0.1400    0.668  119.996  audio_features
# 27   11    -2.278  ...    0.3540    0.829  152.027  audio_features
# 26    4    -3.027  ...    0.0520    0.968  145.003  audio_features
# 37    6    -3.282  ...    0.0740    0.685  103.978  audio_features
# 29    5    -3.975  ...    0.2740    0.486   99.981  audio_features
# 38    5    -3.398  ...    0.1280    0.274  132.052  audio_features
# 39    5    -2.836  ...    0.0433    0.555  107.988  audio_features
#
#                         id                                   uri  \
# 10  2VV1RIhTgeJ4PEMYz6TqDB  spotify:track:2VV1RIhTgeJ4PEMYz6TqDB
# 0   1oen3GpTcA486fTHaT7neg  spotify:track:1oen3GpTcA486fTHaT7neg
# 11  1rp986nzkyAX1wFpxzbwlC  spotify:track:1rp986nzkyAX1wFpxzbwlC
# 1   0t7kjpVLgOYITrSfFCoBEA  spotify:track:0t7kjpVLgOYITrSfFCoBEA
# 13  2ka8U0A2e93hBFA43mbgfy  spotify:track:2ka8U0A2e93hBFA43mbgfy
# 12  4vLqN0bIxIQjlet2mIMBnx  spotify:track:4vLqN0bIxIQjlet2mIMBnx
# 2   1RTW9UthqmZwr8Od6CH4i8  spotify:track:1RTW9UthqmZwr8Od6CH4i8
# 14  46E1ic6n099e76t5J1TbHn  spotify:track:46E1ic6n099e76t5J1TbHn
# 15  462OPOKW0VMbvW9H7HIb0U  spotify:track:462OPOKW0VMbvW9H7HIb0U
# 20  5w18nowVMRZrC5Na9Vxoth  spotify:track:5w18nowVMRZrC5Na9Vxoth
# 0   https://api.spotify.com/v1/audio-analysis/1oen...      202533
# 11  https://api.spotify.com/v1/audio-analysis/1rp9...      213827
# 1   https://api.spotify.com/v1/audio-analysis/0t7k...      201160
# 13  https://api.spotify.com/v1/audio-analysis/2ka8...      197520
# 12  https://api.spotify.com/v1/audio-analysis/4vLq...      233280
# 2   https://api.spotify.com/v1/audio-analysis/1RTW...      265760
# 14  https://api.spotify.com/v1/audio-analysis/46E1...      190821
# 15  https://api.spotify.com/v1/audio-analysis/462O...      220173
# 20  https://api.spotify.com/v1/audio-analysis/5w18...      232333
# 4   https://api.spotify.com/v1/audio-analysis/405S...      224258
# 30  https://api.spotify.com/v1/audio-analysis/6fT9...      214750
# 16  https://api.spotify.com/v1/audio-analysis/6WLE...      208853
# 17  https://api.spotify.com/v1/audio-analysis/457P...      195280
# 18  https://api.spotify.com/v1/audio-analysis/6v9j...      233493
# 19  https://api.spotify.com/v1/audio-analysis/21YN...      221413
# 3   https://api.spotify.com/v1/audio-analysis/4sRQ...      228880
# 6   https://api.spotify.com/v1/audio-analysis/2WkP...      271326
# 21  https://api.spotify.com/v1/audio-analysis/6QTB...      241827
# 8   https://api.spotify.com/v1/audio-analysis/0U9j...      201920
# 31  https://api.spotify.com/v1/audio-analysis/55ku...      208053
# 32  https://api.spotify.com/v1/audio-analysis/6oZe...      199403
# 9   https://api.spotify.com/v1/audio-analysis/3JaM...      235434
# 33  https://api.spotify.com/v1/audio-analysis/5Sus...      220099
# 23  https://api.spotify.com/v1/audio-analysis/2VVq...      226184
# 34  https://api.spotify.com/v1/audio-analysis/1XrP...      187480
# 7   https://api.spotify.com/v1/audio-analysis/6VOG...      188533
# 22  https://api.spotify.com/v1/audio-analysis/0cCm...      201112
# 24  https://api.spotify.com/v1/audio-analysis/23z7...      207744
# 5   https://api.spotify.com/v1/audio-analysis/6kN3...      229253
# 35  https://api.spotify.com/v1/audio-analysis/4SpQ...      208105
# 36  https://api.spotify.com/v1/audio-analysis/3j0x...      209207
# 25  https://api.spotify.com/v1/audio-analysis/2cRT...      239187
# 28  https://api.spotify.com/v1/audio-analysis/2TG8...      231493
# 27  https://api.spotify.com/v1/audio-analysis/6lTB...      256773
# 26  https://api.spotify.com/v1/audio-analysis/3IQ9...      216585
# 37  https://api.spotify.com/v1/audio-analysis/7EZ7...      238920
# 29  https://api.spotify.com/v1/audio-analysis/1Zz7...      186468
# 38  https://api.spotify.com/v1/audio-analysis/5DM5...      224160
# 39  https://api.spotify.com/v1/audio-analysis/7lrL...      234967
#
#    time_signature
# 10              4
# 0               4
# 11              4
# 1               4
# 13              4
# 12              4
# 2               4
# 14              4
# 15              4
# 20              4
# 4               4
# 30              4
# 16              4
# 17              4
# 18              4
# 19              4
# 3               4
# 6               4
# 21              4
# 8               4
# 31              4
# 32              4
# 9               4
# 33              4
# 23              4
# 34              4
# 7               4
# 22              4
# 24              4
# 5               4
# 35              4
# 36              4
# 25              4
# 28              4
# 27              4
# 26              4
# 37              4
# 29              4
# 38              4
# 39              4
#
# [40 rows x 24 columns]

# %%
thirdgen2
# Out:
#        Artist                                          Song Name  \
# 40        BTS                                           Take Two
# 50  SEVENTEEN                                              Super
# 41        BTS            Left and Right (Feat. Jung Kook of BTS)
# 43        BTS  Dreamers [Music from the FIFA World Cup Qatar ...
# 44        BTS                                         The Planet
# 46        BTS                                            Run BTS
# 42        BTS                                        My Universe
# 45        BTS                                           Dynamite
# 47        BTS                                             Butter
# 48        BTS                                          FAKE LOVE
# 49        BTS                        Boy With Luv (feat. Halsey)
# 70        EXO                                          Let Me In
# 61      TWICE                                        SET ME FREE
# 51  SEVENTEEN                                                HOT
# 71        EXO                                          Love Shot
# 62      TWICE                                     Talk that Talk
# 72        EXO                                        Hear Me Out
# 66      TWICE                                              FANCY
# 65      TWICE                                          Hare Hare
# 64      TWICE                                       What is Love
# 63      TWICE                                          The Feels
# 54  SEVENTEEN                                      Rock with you
# 53  SEVENTEEN                                       F*ck My Life
# 67      TWICE                                    I CAN'T STOP ME
# 56  SEVENTEEN                                             _WORLD
# 55  SEVENTEEN                     I Don't Understand But I Luv U
# 69      TWICE                                         CRY FOR ME
# 68      TWICE                                       Feel Special
# 60      TWICE                                  MOONLIGHT SUNRISE
# 57  SEVENTEEN                                          VERY NICE
# 58  SEVENTEEN                                             CHEERS
# 52  SEVENTEEN                                           Darl+ing
# 59  SEVENTEEN                                    Don't Wanna Cry
# 73        EXO                                            The Eve
# 74        EXO                                            Monster
# 75        EXO                                       CALL ME BABY
# 76        EXO                                      LOVE ME RIGHT
# 77        EXO                                              Lotto
# 78        EXO                                          Ko Ko Bop
# 79        EXO                                              Tempo
#
#                         Id Release Date  Popularity  \
# 40  5IAESfJjmOYu7cHyX557kz   2023-06-09          95
# 50  3AOf6YEpxQ894FmrwI9k96   2023-04-24          88
# 41  5Odq8ohlgIbQKMZivbWkEo   2022-10-06          88
# 43  1RDvyOk4WtPCtoqciJwVn8   2022-11-20          87
# 44  4IJsVXbSeGPUrgwpVoHmlg   2023-05-12          86
# 46  69xohKu8C1fsflYAiSNbwM   2022-06-10          85
# 42  46HNZY1i7O6jwTA7Slo2PI   2021-10-15          85
# 45  5QDLhrAOJJdNAmCTJ8xMyW   2020-11-20          85
# 47  6jjYDGxVJsWS0a5wlVF5vS   2022-06-10          81
# 48  6m1TWFMeon7ai9XLOzdbiR   2018-05-18          81
# 49  4a9tbd947vo9K8Vti9JwcI   2019-04-12          81
# 70  5e6hUjvQG2inD4Svco0PvP   2023-06-12          81
# 61  4OtVQ2ZxS7yigIjGz5yKg1   2023-03-10          80
# 51  6I2tqFhk8tq69iursYxuxd   2022-05-27          80
# 71  0yB4jrSwN0bFtFRDR5vyMj   2018-12-13          79
# 62  0RDqNCRBGrSegk16Avfzuq   2022-08-26          79
# 72  44EXniDpWap2veS1gH1svO   2023-06-30          78
# 66  2qQpFbqqkLOGySgNK8wBXt   2019-04-22          78
# 65  0h3dJV8JA5oxPzSF4tkz2t   2023-05-12          78
# 64  3zhbXKFjUDw40pTYyCgt1Y   2018-07-09          78
# 63  308Ir17KlNdlrbVLHWhlLe   2021-11-12          78
# 54  6LnEoRQKMcaFTR5UvaKuBy   2021-10-22          77
# 53  3tgWMPOY4stCdKYj5NjrAe   2023-04-24          77
# 67  37ZtpRBkHcaq6hHy0X98zn   2020-10-26          77
# 56  3QwiidVHfeE9y5jl4n2MTC   2022-07-18          76
# 55  3acGHJqr9xU1cnCEfLX1Lx   2023-04-24          76
# 69  2xtP8RNbo2BEMzLX7tK7aq   2020-12-18          75
# 68  3Hz3tTQwOdM6XkA0ALB2G9   2019-09-23          75
# 60  5IN9W6eUfk3014My9awagX   2023-03-10          75
# 57  1Rrj7KyS2R6SP9CQMDJW1w   2016-07-04          75
# 58  1pdFdv8R6ezIAUUNkn785b   2022-07-18          74
# 52  2j1Es5qEl4pD8GEe2WsYgP   2022-05-27          74
# 59  6Upu6yjkdi0DVI8E3IBZEU   2017-05-22          73
# 73  2ujA6F1cpk3m8lsPE5aKua   2017-07-18          72
# 74  7GbUWl6qLW1gdngbEV2WDJ   2016-06-09          72
# 75  6Rx0ORYPP3GH9rTvGS5Vy8   2015-03-30          71
# 76  1kFevEv3s7Gf6o5xSDR5DL   2015-06-03          70
# 77  6ukWoX4AHV76JdYVdKRPk8   2016-08-18          70
# 78  5EzitieoPnjyKHAq0gfRMa   2017-07-18          69
# 79  4EjUFjzi4ErWjklOA3Aslu   2018-11-02          67
#
#                             Genres  danceability  energy  key  loudness  ...  \
# 40   [k-pop, k-pop boy group, pop]         0.617   0.589    7    -5.978  ...
# 50        [k-pop, k-pop boy group]         0.771   0.880    8    -4.091  ...
# 41   [k-pop, k-pop boy group, pop]         0.881   0.592    2    -4.898  ...
# 43   [k-pop, k-pop boy group, pop]         0.710   0.879    0    -4.218  ...
# 44   [k-pop, k-pop boy group, pop]         0.665   0.848    0    -3.619  ...
# 46   [k-pop, k-pop boy group, pop]         0.724   0.818    8    -3.747  ...
# 42   [k-pop, k-pop boy group, pop]         0.573   0.711    1    -6.268  ...
# 45   [k-pop, k-pop boy group, pop]         0.746   0.765    6    -4.410  ...
# 47   [k-pop, k-pop boy group, pop]         0.759   0.459    8    -5.187  ...
# 48   [k-pop, k-pop boy group, pop]         0.557   0.719    2    -4.515  ...
# 49   [k-pop, k-pop boy group, pop]         0.645   0.862   11    -4.761  ...
# 70        [k-pop, k-pop boy group]         0.549   0.675    1    -4.964  ...
# 61  [k-pop, k-pop girl group, pop]         0.756   0.831    5    -2.536  ...
# 51        [k-pop, k-pop boy group]         0.765   0.777    5    -4.376  ...
# 71        [k-pop, k-pop boy group]         0.689   0.678    5    -4.287  ...
# 62  [k-pop, k-pop girl group, pop]         0.772   0.907    3    -2.438  ...
# 72        [k-pop, k-pop boy group]         0.666   0.727    0    -2.375  ...
# 66  [k-pop, k-pop girl group, pop]         0.697   0.874    5    -2.150  ...
# 65  [k-pop, k-pop girl group, pop]         0.707   0.830    9    -5.331  ...
# 64  [k-pop, k-pop girl group, pop]         0.574   0.909    8    -1.573  ...
# 63  [k-pop, k-pop girl group, pop]         0.808   0.903    9    -2.179  ...
# 54        [k-pop, k-pop boy group]         0.621   0.816   11    -5.242  ...
# 53        [k-pop, k-pop boy group]         0.736   0.685    5    -4.762  ...
# 67  [k-pop, k-pop girl group, pop]         0.657   0.880   10    -3.672  ...
# 56        [k-pop, k-pop boy group]         0.709   0.809    2    -3.198  ...
# 55        [k-pop, k-pop boy group]         0.651   0.786    5    -3.438  ...
# 69  [k-pop, k-pop girl group, pop]         0.702   0.692   10    -5.405  ...
# 68  [k-pop, k-pop girl group, pop]         0.708   0.959    1    -1.338  ...
# 60  [k-pop, k-pop girl group, pop]         0.746   0.780    1    -3.279  ...
# 57        [k-pop, k-pop boy group]         0.746   0.898    3    -2.818  ...
# 58        [k-pop, k-pop boy group]         0.740   0.848    2    -4.697  ...
# 52        [k-pop, k-pop boy group]         0.519   0.695    0    -4.861  ...
# 59        [k-pop, k-pop boy group]         0.781   0.683    0    -4.258  ...
# 73        [k-pop, k-pop boy group]         0.636   0.702    0    -5.352  ...
# 74        [k-pop, k-pop boy group]         0.618   0.760    6    -4.312  ...
# 75        [k-pop, k-pop boy group]         0.692   0.886    1    -2.519  ...
# 76        [k-pop, k-pop boy group]         0.625   0.830    0    -2.330  ...
# 77        [k-pop, k-pop boy group]         0.798   0.867   11    -3.207  ...
# 78        [k-pop, k-pop boy group]         0.749   0.850    0    -4.346  ...
# 79        [k-pop, k-pop boy group]         0.686   0.842    0    -4.423  ...
#
#     liveness  valence    tempo            type                      id  \
# 40    0.3780    0.566   92.991  audio_features  5IAESfJjmOYu7cHyX557kz
# 50    0.1670    0.347  137.018  audio_features  3AOf6YEpxQ894FmrwI9k96
# 41    0.0901    0.719  101.058  audio_features  5Odq8ohlgIbQKMZivbWkEo
# 43    0.4390    0.341  114.993  audio_features  1RDvyOk4WtPCtoqciJwVn8
# 44    0.2000    0.687  119.986  audio_features  4IJsVXbSeGPUrgwpVoHmlg
# 46    0.0358    0.696   77.004  audio_features  69xohKu8C1fsflYAiSNbwM
# 42    0.3280    0.470  105.006  audio_features  46HNZY1i7O6jwTA7Slo2PI
# 45    0.0936    0.737  114.044  audio_features  5QDLhrAOJJdNAmCTJ8xMyW
# 47    0.0788    0.695  109.997  audio_features  6jjYDGxVJsWS0a5wlVF5vS
# 48    0.3060    0.345   77.502  audio_features  6m1TWFMeon7ai9XLOzdbiR
# 49    0.1930    0.803  119.947  audio_features  4a9tbd947vo9K8Vti9JwcI
# 70    0.1710    0.373   84.013  audio_features  5e6hUjvQG2inD4Svco0PvP
# 61    0.0499    0.703  113.025  audio_features  4OtVQ2ZxS7yigIjGz5yKg1
# 51    0.3380    0.640  111.944  audio_features  6I2tqFhk8tq69iursYxuxd
# 71    0.0889    0.335  145.883  audio_features  0yB4jrSwN0bFtFRDR5vyMj
# 62    0.3340    0.783  119.973  audio_features  0RDqNCRBGrSegk16Avfzuq
# 72    0.3050    0.591   92.056  audio_features  44EXniDpWap2veS1gH1svO
# 66    0.6270    0.775  132.018  audio_features  2qQpFbqqkLOGySgNK8wBXt
# 68  https://api.spotify.com/v1/audio-analysis/3Hz3...      206867
# 60  https://api.spotify.com/v1/audio-analysis/5IN9...      180320
# 57  https://api.spotify.com/v1/audio-analysis/1Rrj...      192093
# 58  https://api.spotify.com/v1/audio-analysis/1pdF...      181467
# 52  https://api.spotify.com/v1/audio-analysis/2j1E...      176560
# 59  https://api.spotify.com/v1/audio-analysis/6Upu...      203427
# 73  https://api.spotify.com/v1/audio-analysis/2ujA...      176026
# 74  https://api.spotify.com/v1/audio-analysis/7GbU...      221341
# 75  https://api.spotify.com/v1/audio-analysis/6Rx0...      211013
# 76  https://api.spotify.com/v1/audio-analysis/1kFe...      205129
# 77  https://api.spotify.com/v1/audio-analysis/6ukW...      189775
# 78  https://api.spotify.com/v1/audio-analysis/5Ezi...      190423
# 79  https://api.spotify.com/v1/audio-analysis/4EjU...      224483
#
#    time_signature
# 40              4
# 50              4
# 41              4
# 43              4
# 44              4
# 46              4
# 42              4
# 45              4
# 47              4
# 48              4
# 49              4
# 70              4
# 61              4
# 51              4
# 71              4
# 62              4
# 72              4
# 66              4
# 65              4
# 64              4
# 63              4
# 54              4
# 53              4
# 67              4
# 56              4
# 55              4
# 69              4
# 68              4
# 60              4
# 57              4
# 58              4
# 52              4
# 59              4
# 73              4
# 74              4
# 75              4
# 76              4
# 77              4
# 78              4
# 79              4
#
# [40 rows x 24 columns]

# %%
fourthgen2
# Out:
#           Artist                                          Song Name  \
# 80      NEWJEANS                                                OMG
# 90   LE SSERAFIM                    UNFORGIVEN (feat. Nile Rodgers)
# 81      NEWJEANS                                              Ditto
# 100      ENHYPEN                                            Bite Me
# 82      NEWJEANS                                           Hype Boy
# 92   LE SSERAFIM                 Eve, Psyche & The Bluebeard’s wife
# 83      NEWJEANS                                          Attention
# 84      NEWJEANS                                          Super Shy
# 110        ATEEZ                      BOUNCY (K-HOT CHILLI PEPPERS)
# 86      NEWJEANS                                             Cookie
# 85      NEWJEANS                                          New Jeans
# 101      ENHYPEN                                        Drunk-Dazed
# 102      ENHYPEN                                      Polaroid Love
# 87      NEWJEANS                                               Hurt
# 94   LE SSERAFIM                                        Sour Grapes
# 105      ENHYPEN                                              Bills
# 104      ENHYPEN                              Sacrifice (Eat Me Up)
# 91   LE SSERAFIM                                        ANTIFRAGILE
# 103      ENHYPEN                                              FEVER
# 88      NEWJEANS                                               Zero
# 106      ENHYPEN                                           Chaconne
# 107      ENHYPEN                                          SHOUT OUT
# 93   LE SSERAFIM                               FEARLESS (2023 Ver.)
# 111        ATEEZ                                            HALAZIA
# 108      ENHYPEN                                               Fate
# 97   LE SSERAFIM      Good Parts (when the quality is bad but I am)
# 109      ENHYPEN                      Future Perfect (Pass the MIC)
# 112        ATEEZ                                             DJANGO
# 89      NEWJEANS  Be Who You Are (Real Magic) (feat. JID, NewJea...
# 98   LE SSERAFIM                       No-Return (Into the unknown)
# 113        ATEEZ                                         This World
# 114        ATEEZ                                               Dune
# 115        ATEEZ                                          Guerrilla
# 116        ATEEZ                                             Outlaw
#
#                         Genres  danceability  energy  key  loudness  ...  \
# 80   [k-pop, k-pop girl group]         0.804   0.771    9    -4.067  ...
# 90          [k-pop girl group]         0.795   0.875    4    -4.079  ...
# 81   [k-pop, k-pop girl group]         0.814   0.641    6    -5.957  ...
# 100   [anime, k-pop boy group]         0.795   0.781    1    -4.647  ...
# 82   [k-pop, k-pop girl group]         0.593   0.935    4    -3.430  ...
# 92          [k-pop girl group]         0.663   0.872   11    -5.056  ...
# 83   [k-pop, k-pop girl group]         0.811   0.648   10    -3.684  ...
# 84   [k-pop, k-pop girl group]         0.776   0.817    5    -6.018  ...
# 110   [k-pop, k-pop boy group]         0.532   0.896    8    -4.356  ...
# 86   [k-pop, k-pop girl group]         0.847   0.638    0    -3.764  ...
# 85   [k-pop, k-pop girl group]         0.807   0.721    4    -6.211  ...
# 101   [anime, k-pop boy group]         0.599   0.869    5    -5.174  ...
# 102   [anime, k-pop boy group]         0.738   0.670    7    -3.766  ...
# 87   [k-pop, k-pop girl group]         0.599   0.446   10    -6.511  ...
# 94          [k-pop girl group]         0.779   0.801    6    -5.564  ...
# 105   [anime, k-pop boy group]         0.695   0.579    8    -5.895  ...
# 104   [anime, k-pop boy group]         0.536   0.727    0    -4.707  ...
# 91          [k-pop girl group]         0.879   0.784   10    -3.944  ...
# 103   [anime, k-pop boy group]         0.600   0.713    6    -5.079  ...
# 88   [k-pop, k-pop girl group]         0.705   0.653    1    -7.407  ...
# 106   [anime, k-pop boy group]         0.646   0.644    6    -6.192  ...
# 107   [anime, k-pop boy group]         0.495   0.844    2    -3.650  ...
# 93          [k-pop girl group]         0.856   0.615    7    -7.226  ...
# 111   [k-pop, k-pop boy group]         0.482   0.884    6    -4.538  ...
# 108   [anime, k-pop boy group]         0.504   0.741    8    -7.470  ...
# 97          [k-pop girl group]         0.785   0.679    0    -4.907  ...
# 109   [anime, k-pop boy group]         0.658   0.900    9    -3.479  ...
# 112   [k-pop, k-pop boy group]         0.761   0.826    5    -4.184  ...
# 89   [k-pop, k-pop girl group]         0.657   0.875    2    -4.206  ...
# 98          [k-pop girl group]         0.753   0.717    7    -4.672  ...
# 113   [k-pop, k-pop boy group]         0.457   0.834    2    -5.398  ...
# 114   [k-pop, k-pop boy group]         0.515   0.926    9    -3.769  ...
# 115   [k-pop, k-pop boy group]         0.555   0.890    9    -5.349  ...
# 116   [k-pop, k-pop boy group]         0.736   0.774    5    -5.031  ...
# 117   [k-pop, k-pop boy group]         0.558   0.931    1    -3.484  ...
# 118   [k-pop, k-pop boy group]         0.692   0.835    6    -4.978  ...
# 99          [k-pop girl group]         0.716   0.779    9    -3.735  ...
# 119   [k-pop, k-pop boy group]         0.572   0.964    4    -1.949  ...
# 95          [k-pop girl group]         0.771   0.747    4    -3.407  ...
# 96          [k-pop girl group]         0.597   0.766    9    -4.192  ...
#
#      liveness  valence    tempo            type                      id  \
# 80     0.1080    0.739  126.956  audio_features  65FftemJ1DbbZ45DUfHJXE
# 90     0.1070    0.375  104.008  audio_features  51vRumtqbkNW9wrKfESwfu
# 83   https://api.spotify.com/v1/audio-analysis/2pIU...      180067
# 84   https://api.spotify.com/v1/audio-analysis/5sdQ...      154667
# 110  https://api.spotify.com/v1/audio-analysis/5KyO...      187311
# 86   https://api.spotify.com/v1/audio-analysis/2DwU...      235562
# 85   https://api.spotify.com/v1/audio-analysis/6rdk...      108987
# 101  https://api.spotify.com/v1/audio-analysis/1wcr...      193260
# 102  https://api.spotify.com/v1/audio-analysis/5elW...      184602
# 87   https://api.spotify.com/v1/audio-analysis/5exp...      177947
# 94   https://api.spotify.com/v1/audio-analysis/6wBp...      196540
# 105  https://api.spotify.com/v1/audio-analysis/2nfl...      175752
# 104  https://api.spotify.com/v1/audio-analysis/58It...      202488
# 91   https://api.spotify.com/v1/audio-analysis/0bMo...      184444
# 103  https://api.spotify.com/v1/audio-analysis/0Uzy...      172107
# 88   https://api.spotify.com/v1/audio-analysis/5LMo...      154194
# 106  https://api.spotify.com/v1/audio-analysis/7nBj...      213706
# 107  https://api.spotify.com/v1/audio-analysis/5Z2D...      228116
# 93   https://api.spotify.com/v1/audio-analysis/4K8j...      168437
# 111  https://api.spotify.com/v1/audio-analysis/5cTn...      197026
# 108  https://api.spotify.com/v1/audio-analysis/0iLy...      151670
# 97   https://api.spotify.com/v1/audio-analysis/1sZB...      156355
# 109  https://api.spotify.com/v1/audio-analysis/6PRy...      180750
# 112  https://api.spotify.com/v1/audio-analysis/5Ku5...      191923
# 89   https://api.spotify.com/v1/audio-analysis/7fcZ...      189714
# 98   https://api.spotify.com/v1/audio-analysis/6DSG...      184824
# 113  https://api.spotify.com/v1/audio-analysis/6QDc...      212106
# 114  https://api.spotify.com/v1/audio-analysis/1Cwz...      195484
# 115  https://api.spotify.com/v1/audio-analysis/0tYZ...      207922
# 116  https://api.spotify.com/v1/audio-analysis/6UM7...      199307
# 117  https://api.spotify.com/v1/audio-analysis/2fZ1...      186434
# 118  https://api.spotify.com/v1/audio-analysis/3zmr...      196670
# 99   https://api.spotify.com/v1/audio-analysis/05Rl...      198233
# 119  https://api.spotify.com/v1/audio-analysis/6k67...      199013
# 95   https://api.spotify.com/v1/audio-analysis/2ahp...      201895
# 96   https://api.spotify.com/v1/audio-analysis/7mYw...      196365
#
#     time_signature
# 80               4
# 90               4
# 81               4
# 100              4
# 82               4
# 92               4
# 83               4
# 84               4
# 110              4
# 86               4
# 85               4
# 101              4
# 102              4
# 87               4
# 94               4
# 105              4
# 104              4
# 91               4
# 103              4
# 88               4
# 106              4
# 107              4
# 93               4
# 111              4
# 108              3
# 97               4
# 109              4
# 112              4
# 89               4
# 98               4
# 113              4
# 114              4
# 115              4
# 116              4
# 117              4
# 118              4
# 99               4
# 119              4
# 95               4
# 96               4
#
# [40 rows x 24 columns]

# %% [markdown]
# ## CLUSTERING

# %%
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']
data = secondgen2.loc[:, features].values

#Standardize the Data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# K-means Clustering
min_clusters = 2
max_clusters = 10
silhouette_scores = []

for n_clusters in range(min_clusters, max_clusters+1):
    kmeans = KMeans(n_clusters=n_clusters, n_init='auto')
    kmeans.fit(scaled_data)
    score = silhouette_score(scaled_data, kmeans.labels_)
    silhouette_scores.append(score)

#plot
plt.plot(range(min_clusters, max_clusters+1), silhouette_scores, marker='o')
plt.title('Silhouette Score for Different Numbers of Clusters (2nd Gen)')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']
data = thirdgen2.loc[:, features].values

#Standardize the Data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# K-means Clustering
min_clusters = 2
max_clusters = 10
silhouette_scores = []

for n_clusters in range(min_clusters, max_clusters+1):
    kmeans = KMeans(n_clusters=n_clusters, n_init='auto')
    kmeans.fit(scaled_data)
    score = silhouette_score(scaled_data, kmeans.labels_)
    silhouette_scores.append(score)

#plot
plt.plot(range(min_clusters, max_clusters+1), silhouette_scores, marker='o')
plt.title('Silhouette Score for Different Numbers of Clusters (3rd Gen)')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']
data = fourthgen2.loc[:, features].values

#Standardize the Data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# K-means Clustering
min_clusters = 2
max_clusters = 10
silhouette_scores = []

for n_clusters in range(min_clusters, max_clusters+1):
    kmeans = KMeans(n_clusters=n_clusters, n_init='auto')
    kmeans.fit(scaled_data)
    score = silhouette_score(scaled_data, kmeans.labels_)
    silhouette_scores.append(score)

#plot
plt.plot(range(min_clusters, max_clusters+1), silhouette_scores, marker='o')
plt.title('Silhouette Score for Different Numbers of Clusters (4th Gen)')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness','liveness', 'valence', 'tempo']
data = final_df.loc[:, features].values

#Standardize the Data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# K-means Clustering
min_clusters = 2
max_clusters = 10
silhouette_scores = []

for n_clusters in range(min_clusters, max_clusters+1):
    kmeans = KMeans(n_clusters=n_clusters, n_init='auto')
    kmeans.fit(scaled_data)
    score = silhouette_score(scaled_data, kmeans.labels_)
    silhouette_scores.append(score)

#plot
plt.plot(range(min_clusters, max_clusters+1), silhouette_scores, marker='o')
plt.title('Silhouette Score for Different Numbers of Clusters (All Gen)')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
#Clusters 
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters, n_init='auto')
kmeans.fit(scaled_data)
final_df['Cluster'] = kmeans.labels_

# add cluster column
secondgen2 = secondgen2.merge(final_df[['Artist', 'Cluster']], on='Artist')
thirdgen2 = thirdgen2.merge(final_df[['Artist', 'Cluster']], on='Artist')
fourthgen2 = fourthgen2.merge(final_df[['Artist', 'Cluster']], on='Artist')

# Plot 
plt.figure(figsize=(10, 5))

# Second gen artists
plt.subplot(1, 3, 1)
secondgen2['Cluster'].value_counts().sort_index().plot(kind='bar')
plt.title('Artists from 2nd gen')
plt.xlabel('Cluster')
plt.ylabel('Count')

# Third gen artists
plt.subplot(1, 3, 2)
thirdgen2['Cluster'].value_counts().sort_index().plot(kind='bar')
plt.title('Artists from 3rd gen')
plt.xlabel('Cluster')
plt.ylabel('Count')

# Fourth gen artists
plt.subplot(1, 3, 3)
fourthgen2['Cluster'].value_counts().sort_index().plot(kind='bar')
plt.title('Artists from 4th_gen')
plt.xlabel('Cluster')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']

for feature in features:
    # Scatter plot of feature vs. popularity
    plt.scatter(secondgen2[feature], secondgen2['Popularity'], c=secondgen2['Cluster'], cmap='spring')
    plt.title(f'Clustering Results - {feature}')
    plt.xlabel(feature)
    plt.ylabel('Popularity')
    plt.show()

# %%
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']

for feature in features:
    # Scatter plot of feature vs. popularity
    plt.scatter(thirdgen2[feature], thirdgen2['Popularity'], c=thirdgen2['Cluster'], cmap='spring')
    plt.title(f'Clustering Results - {feature}')
    plt.xlabel(feature)
    plt.ylabel('Popularity')
    plt.show()

# %%
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']

for feature in features:
    # Scatter plot of feature vs. popularity
    plt.scatter(fourthgen2[feature], fourthgen2['Popularity'], c=fourthgen2['Cluster'], cmap='spring')
    plt.title(f'Clustering Results - {feature}')
    plt.xlabel(feature)
    plt.ylabel('Popularity')
    plt.show()

# %%
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']

for feature in features:
    # Scatter plot of feature vs. popularity
    plt.scatter(final_df[feature], final_df['Popularity'], c=final_df['Cluster'], cmap='spring')
    plt.title(f'Clustering Results - {feature}')
    plt.xlabel(feature)
    plt.ylabel('Popularity')
    plt.show()

# %% [markdown]
# ## RELEASE PATTERNS ACCROSS GENERATIONS

# %% [markdown]
# RELEASE PATTERNS FOR TOP TRACKS

# %%
plt.figure(figsize=(20, 15))
release_counts = final_df['Release Date'].value_counts().sort_index()
release_counts.plot(kind='line', marker='o')
plt.title('Release Dates of Songs')
plt.xlabel('Release Date')
plt.ylabel('Count')
plt.xticks(range(len(release_counts.index)), release_counts.index, rotation=45, ha='right')
plt.show()

# %%
specific_dates = ['2010-01-28', '2021-04-26', '2023-05-01']

for date in specific_dates:
    albums = final_df[final_df['Release Date'] == date]['Song Name'].unique()
    print('Songs released on', date, ':')
    for album in albums:
        print('-', album)
    print()
# Out:
# Songs released on 2010-01-28 :
# - Gee
# - Genie
# - Oh!
#
# Songs released on 2021-04-26 :
# - Drunk-Dazed
# - FEVER
#
# Songs released on 2023-05-01 :
# - UNFORGIVEN (feat. Nile Rodgers)
# - ANTIFRAGILE
# - Eve, Psyche & The Bluebeard’s wife
# - FEARLESS (2023 Ver.)
# - Blue Flame (2023 Ver.)
# - Impurities
# - No-Return (Into the unknown)
# - Fire in the belly

# %% [markdown]
# Trends:
#
# july
# jan
# april
# june july
# aug
# march
# may
# may
# june
#
#
# A lot of spring/summer releases
#
# Since I only have the top tracks of each artists, the number of songs released on a specific date does not show
# the actual number of songs released on that date since not all songs from the album or ep are necessarily top
# tracks

# %% [markdown]
# RELEASE PATTERNS FOR ALBUMS

# %%
# Create an empty DataFrame to store the album information
artist_albums = pd.DataFrame(columns=['Artist', 'Album', 'Release Date'])

# Loop through each artist in the final_df
for artist in final_df['Artist'].unique():
    # Search for artist
    results = sp.search(q='artist:' + artist, type='artist', limit=1)
    if results['artists']['items']:
        artist_uri = results['artists']['items'][0]['uri']
        
        # Get the albums of the artist
        albums = sp.artist_albums(artist_uri, album_type='album', limit=50)
        
        # Extract album information
        album_data = []
        for album in albums['items']:
            album_name = album['name']
            release_date = album['release_date']
            
            # Append the album information
            album_data.append({'Artist': artist, 'Album': album_name, 'Release Date': release_date})
        
        # Concatenate the album data to the DataFrame
        artist_albums = pd.concat([artist_albums, pd.DataFrame(album_data)])

# Print the resulting DataFrame
artist_albums
# Out:
#               Artist                              Album Release Date
# 0   Girls Generation          FOREVER 1 - The 7th Album   2022-08-05
# 1   Girls Generation      Holiday Night - The 6th Album   2017-08-04
# 2   Girls Generation         Lion Heart - The 5th Album   2015-08-19
# 3   Girls Generation        2011 Girls' Generation Tour   2013-11-04
# 4   Girls Generation        I GOT A BOY - The 4th Album   2013-01-01
# ..               ...                                ...          ...
# 3              ATEEZ                    Into the A to Z   2021-03-24
# 4              ATEEZ                ZERO : FEVER Part.2   2021-03-01
# 5              ATEEZ                ZERO : FEVER Part.1   2020-07-29
# 6              ATEEZ  TREASURE EP. EXTRA: Shift The Map   2019-12-04
# 7              ATEEZ     TREASURE EP.FIN: All To Action   2019-10-08
#
# [145 rows x 3 columns]

# %%
plt.figure(figsize=(30, 30))
release_counts = artist_albums['Release Date'].value_counts().sort_index()
release_counts.plot(kind='line', marker='o')
plt.title('Release Dates of Albums')
plt.xlabel('Release Date')
plt.ylabel('Count')
plt.xticks(range(len(release_counts.index)), release_counts.index, rotation=45, ha='right')
plt.show()

# %%
# Set the desired start and end dates
start_date = '2014-01-01'
end_date = '2018-12-31'

plt.figure(figsize=(10, 6))
release_counts = artist_albums['Release Date'].value_counts().sort_index()

# Filter the release_counts DataFrame based on the date range
filtered_counts = release_counts.loc[start_date:end_date]

filtered_counts.plot(kind='line', marker='o')
plt.title('Release Dates of Albums')
plt.xlabel('Release Date')
plt.ylabel('Count')
plt.xticks(range(len(filtered_counts.index)), filtered_counts.index, rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## POPULARITY COMPARISON

# %%
#Popularity by group

# Group by artist and mean popularity
popularity_comparison = final_df.groupby('Artist')['Popularity'].mean().sort_values(ascending=False)

# plot
plt.figure(figsize=(10, 6))
popularity_comparison.plot(kind='bar')
plt.title('Popularity Comparison Between Artists')
plt.xlabel('Artist')
plt.ylabel('Average Popularity')
plt.show()

# %%
group_followers = {}

# List of K-pop group names
group_names = ['Girls Generation', 'SHINEE', 'Super Junior', 'Apink', 'BTS', 'SEVENTEEN', 'TWICE', 'EXO', 'NEWJEANS', 'LE SSERAFIM', 'ENHYPEN', 'ATEEZ']

# Iterate through each group name and retrieve the followers count
for group_name in group_names:
    result = sp.search(q='artist:' + group_name, type='artist', limit=1)
    if len(result['artists']['items']) > 0:
        artist = result['artists']['items'][0]
        group_followers[group_name] = artist['followers']['total']
    else:
        group_followers[group_name] = 0

# Sort the group_followers dictionary based on followers count in ascending order
sorted_group_followers = {k: v for k, v in sorted(group_followers.items(), key=lambda item: item[1])}

# Print the followers count for each group in ascending order
for group, followers in sorted_group_followers.items():
    print(f"{group}: {followers} followers")
# Out:
# Apink: 1215067 followers
# Super Junior: 2393380 followers
# Girls Generation: 2439591 followers
# LE SSERAFIM: 2532600 followers
# ATEEZ: 2989215 followers
# SHINEE: 3025530 followers
# NEWJEANS: 3901642 followers
# ENHYPEN: 5938955 followers
# SEVENTEEN: 9631025 followers
# EXO: 9662392 followers
# TWICE: 18147898 followers
# BTS: 67021681 followers

# %%
groups = list(sorted_group_followers.keys())
followers_count = list(sorted_group_followers.values())

plt.bar(groups, followers_count)
plt.xticks(rotation=90)
plt.xlabel('K-pop Group')
plt.ylabel('Followers Count')
plt.title('Followers Count for K-pop Groups')
plt.tight_layout()

# %% [markdown]
# ## PREDICTED POPULARITY VS ACTUAL POPULARITY

# %%
# Select features and target variable
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']
target = 'Popularity'

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(secondgen2[features], secondgen2[target], test_size=0.2, random_state=42)

# Train the linear regression model
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = regression_model.predict(X_test)

# Evaluate the model performance
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Plot
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Popularity')
plt.ylabel('Predicted Popularity')
plt.title('Regression: Predicted vs. Actual Popularity (Second Gen)')
plt.show()
# Out:
# Mean Squared Error: 36.362142947479356

# %%
# Select features and target variable
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']
target = 'Popularity'

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(thirdgen2[features], thirdgen2[target], test_size=0.2, random_state=42)

# Train the linear regression model
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = regression_model.predict(X_test)

# Evaluate the model performance
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# plot
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Popularity')
plt.ylabel('Predicted Popularity')
plt.title('Regression: Predicted vs. Actual Popularity (Third Gen)')
plt.show()
# Out:
# Mean Squared Error: 24.375105614547422

# %%
# Select features and target variable
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']
target = 'Popularity'

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(fourthgen2[features], fourthgen2[target], test_size=0.2, random_state=42)

# Train the linear regression model
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = regression_model.predict(X_test)

# Evaluate the model performance
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Plot
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Popularity')
plt.ylabel('Predicted Popularity')
plt.title('Regression: Predicted vs. Actual Popularity (Fourth Gen)')
plt.show()
# Out:
# Mean Squared Error: 32.29895298407602

# %% [markdown]
# ## PLAYLIST FOLLOWERS

# %%
def getPlaylistFollowerCount(user, playlist_id):
    playlist = sp.user_playlist(user, playlist_id)
    return playlist['followers']['total']

# %%
getPlaylistFollowerCount('azizazhariramli', '2olOnYOj1paGcLOTbkPTdZ')
# Out:
# 2768

# %%
getPlaylistFollowerCount('husnaannisa', '6x9G992JNwDVO5DqoOOreA')
# Out:
# 2642

# %%
getPlaylistFollowerCount('delvianaftsr', '1GSdwx9OMXReZLW8V5G40t')
# Out:
# 1

# %% [markdown]
# ## RANDOM

# %%
# Get features of a single song
song_id = '70t7Q6AYG6ZgTYmJWcnkUM'  
sp.audio_features(song_id)[0]
# Out:
# {'danceability': 0.683,
#  'energy': 0.875,
#  'key': 4,
#  'loudness': -4.866,
#  'mode': 0,
#  'speechiness': 0.0549,
#  'acousticness': 0.0115,
#  'instrumentalness': 0,
#  'liveness': 0.084,
#  'valence': 0.384,
#  'tempo': 122.002,
#  'type': 'audio_features',
#  'id': '70t7Q6AYG6ZgTYmJWcnkUM',
#  'uri': 'spotify:track:70t7Q6AYG6ZgTYmJWcnkUM',
#  'track_href': 'https://api.spotify.com/v1/tracks/70t7Q6AYG6ZgTYmJWcnkUM',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/70t7Q6AYG6ZgTYmJWcnkUM',
#  'duration_ms': 183853,
#  'time_signature': 4}

# %%
sp.audio_features(song_id)[0]
# Out:
# {'danceability': 0.683,
#  'energy': 0.875,
#  'key': 4,
#  'loudness': -4.866,
#  'mode': 0,
#  'speechiness': 0.0549,
#  'acousticness': 0.0115,
#  'instrumentalness': 0,
#  'liveness': 0.084,
#  'valence': 0.384,
#  'tempo': 122.002,
#  'type': 'audio_features',
#  'id': '70t7Q6AYG6ZgTYmJWcnkUM',
#  'uri': 'spotify:track:70t7Q6AYG6ZgTYmJWcnkUM',
#  'track_href': 'https://api.spotify.com/v1/tracks/70t7Q6AYG6ZgTYmJWcnkUM',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/70t7Q6AYG6ZgTYmJWcnkUM',
#  'duration_ms': 183853,
#  'time_signature': 4}

# %%
def get_recommendations(track_name):
    # Get track URI
    results = sp.search(q=track_name, type='track')
    track_uri = results['tracks']['items'][0]['uri']

    # Get recommended tracks
    recommendations = sp.recommendations(seed_tracks=[track_uri])['tracks']
    return recommendations

get_recommendations('UNFORGIVEN')
# Out:
# [{'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5R7AMwDeroq6Ls0COQYpS4'},
#      'href': 'https://api.spotify.com/v1/artists/5R7AMwDeroq6Ls0COQYpS4',
#      'id': '5R7AMwDeroq6Ls0COQYpS4',
#      'name': 'Kep1er',
#      'type': 'artist',
#      'uri': 'spotify:artist:5R7AMwDeroq6Ls0COQYpS4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3knTfpvtA87E82OLyDJJWS'},
#    'href': 'https://api.spotify.com/v1/albums/3knTfpvtA87E82OLyDJJWS',
#    'id': '3knTfpvtA87E82OLyDJJWS',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273671447fb98332fb47730f90f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02671447fb98332fb47730f90f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851671447fb98332fb47730f90f',
#      'width': 64}],
#    'name': '<FLY-BY> - Special Edition -',
#    'release_date': '2023-03-15',
#    'release_date_precision': 'day',
#    'total_tracks': 5,
#    'type': 'album',
#    'uri': 'spotify:album:3knTfpvtA87E82OLyDJJWS'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5R7AMwDeroq6Ls0COQYpS4'},
#     'href': 'https://api.spotify.com/v1/artists/5R7AMwDeroq6Ls0COQYpS4',
#     'id': '5R7AMwDeroq6Ls0COQYpS4',
#     'name': 'Kep1er',
#     'type': 'artist',
#     'uri': 'spotify:artist:5R7AMwDeroq6Ls0COQYpS4'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 211533,
#   'explicit': False,
#   'external_ids': {'isrc': 'KRA492300173'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4lEyfMaUwdioK1MxfSVBPw'},
#   'href': 'https://api.spotify.com/v1/tracks/4lEyfMaUwdioK1MxfSVBPw',
#   'id': '4lEyfMaUwdioK1MxfSVBPw',
#   'is_local': False,
#   'name': 'tOgether fOrever',
#   'popularity': 51,
#   'preview_url': 'https://p.scdn.co/mp3-preview/553d5a2bedf99667951b7eeb6a03f2acf10b57bc?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:4lEyfMaUwdioK1MxfSVBPw'},
#  {'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2nkZR6LwPxaAVtaVitNIPT'},
#      'href': 'https://api.spotify.com/v1/artists/2nkZR6LwPxaAVtaVitNIPT',
#      'id': '2nkZR6LwPxaAVtaVitNIPT',
#      'name': 'LEE CHAE YEON',
#      'type': 'artist',
#      'uri': 'spotify:artist:2nkZR6LwPxaAVtaVitNIPT'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6ksAgHMbcJbfxwwO799483'},
#    'href': 'https://api.spotify.com/v1/albums/6ksAgHMbcJbfxwwO799483',
#    'id': '6ksAgHMbcJbfxwwO799483',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b589bc0468740f56049a87ba',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b589bc0468740f56049a87ba',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b589bc0468740f56049a87ba',
#      'width': 64}],
#    'name': 'HUSH RUSH',
#    'release_date': '2022-10-12',
#    'release_date_precision': 'day',
#    'total_tracks': 4,
#    'type': 'album',
#    'uri': 'spotify:album:6ksAgHMbcJbfxwwO799483'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2nkZR6LwPxaAVtaVitNIPT'},
#     'href': 'https://api.spotify.com/v1/artists/2nkZR6LwPxaAVtaVitNIPT',
#     'id': '2nkZR6LwPxaAVtaVitNIPT',
#     'name': 'LEE CHAE YEON',
#     'type': 'artist',
#     'uri': 'spotify:artist:2nkZR6LwPxaAVtaVitNIPT'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 207400,
#   'explicit': False,
#   'external_ids': {'isrc': 'KRNAR2203899'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0P2LW3jbuJLpH2mwg0lLzn'},
#   'href': 'https://api.spotify.com/v1/tracks/0P2LW3jbuJLpH2mwg0lLzn',
#   'id': '0P2LW3jbuJLpH2mwg0lLzn',
#   'is_local': False,
#   'name': 'HUSH RUSH',
#   'popularity': 58,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cb068999b6dce0b75f33e8d46eb08e1969d2e48e?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0P2LW3jbuJLpH2mwg0lLzn'},
#  {'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qBsABYUrxg9afpMtyoFKz'},
#      'href': 'https://api.spotify.com/v1/artists/1qBsABYUrxg9afpMtyoFKz',
#      'id': '1qBsABYUrxg9afpMtyoFKz',
#      'name': 'WayV',
#      'type': 'artist',
#      'uri': 'spotify:artist:1qBsABYUrxg9afpMtyoFKz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/75o2o6EZW8Q4r9xmL1XmRx'},
#    'href': 'https://api.spotify.com/v1/albums/75o2o6EZW8Q4r9xmL1XmRx',
#    'id': '75o2o6EZW8Q4r9xmL1XmRx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b66bd4fbdac56e535958b17d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b66bd4fbdac56e535958b17d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b66bd4fbdac56e535958b17d',
#      'width': 64}],
#    'name': 'Welcome To My Paradise',
#    'release_date': '2023-05-06',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:75o2o6EZW8Q4r9xmL1XmRx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qBsABYUrxg9afpMtyoFKz'},
#     'href': 'https://api.spotify.com/v1/artists/1qBsABYUrxg9afpMtyoFKz',
#     'id': '1qBsABYUrxg9afpMtyoFKz',
#     'name': 'WayV',
#     'type': 'artist',
#     'uri': 'spotify:artist:1qBsABYUrxg9afpMtyoFKz'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 195442,
#   'explicit': False,
#   'external_ids': {'isrc': 'JPB602302152'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3peCAGvd86EKfjlYELknUB'},
#   'href': 'https://api.spotify.com/v1/tracks/3peCAGvd86EKfjlYELknUB',
#   'id': '3peCAGvd86EKfjlYELknUB',
#   'is_local': False,
#   'name': 'Welcome To My Paradise',
#   'popularity': 54,
#   'preview_url': 'https://p.scdn.co/mp3-preview/03858a3711dec7c796ac26f262952bc35b650bd1?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3peCAGvd86EKfjlYELknUB'},
#  {'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49pGKUCSjzaCfv8gdTWG98'},
#      'href': 'https://api.spotify.com/v1/artists/49pGKUCSjzaCfv8gdTWG98',
#      'id': '49pGKUCSjzaCfv8gdTWG98',
#      'name': 'BOYS PLANET',
#      'type': 'artist',
#      'uri': 'spotify:artist:49pGKUCSjzaCfv8gdTWG98'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5F3uLyGvCV3QINuGZkdOfS'},
#    'href': 'https://api.spotify.com/v1/albums/5F3uLyGvCV3QINuGZkdOfS',
#    'id': '5F3uLyGvCV3QINuGZkdOfS',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f86c5c45e58e55a2e16ac64f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f86c5c45e58e55a2e16ac64f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f86c5c45e58e55a2e16ac64f',
#      'width': 64}],
#    'name': 'BOYS PLANET - FINAL TOP9 BATTLE',
#    'release_date': '2023-04-21',
#    'release_date_precision': 'day',
#    'total_tracks': 3,
#    'type': 'album',
#    'uri': 'spotify:album:5F3uLyGvCV3QINuGZkdOfS'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49pGKUCSjzaCfv8gdTWG98'},
#     'href': 'https://api.spotify.com/v1/artists/49pGKUCSjzaCfv8gdTWG98',
#     'id': '49pGKUCSjzaCfv8gdTWG98',
#     'name': 'BOYS PLANET',
#     'type': 'artist',
#     'uri': 'spotify:artist:49pGKUCSjzaCfv8gdTWG98'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 226840,
#   'explicit': False,
#   'external_ids': {'isrc': 'KRA492300300'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4eSaL5oRwSHcMGvmIrgYzP'},
#   'href': 'https://api.spotify.com/v1/tracks/4eSaL5oRwSHcMGvmIrgYzP',
#   'id': '4eSaL5oRwSHcMGvmIrgYzP',
#   'is_local': False,
#   'name': 'Hot Summer',
#   'popularity': 68,
#   'preview_url': 'https://p.scdn.co/mp3-preview/bf5a58e65eb0fbf92defc6b5dfd678f06cc94be3?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:4eSaL5oRwSHcMGvmIrgYzP'},
#  {'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3JjvsPeGMbDJqsphe2z8xU'},
#      'href': 'https://api.spotify.com/v1/artists/3JjvsPeGMbDJqsphe2z8xU',
#      'id': '3JjvsPeGMbDJqsphe2z8xU',
#      'name': 'P1Harmony',
#      'type': 'artist',
#      'uri': 'spotify:artist:3JjvsPeGMbDJqsphe2z8xU'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/13kHQp4zyK5jBpsFZmTvHz'},
#    'href': 'https://api.spotify.com/v1/albums/13kHQp4zyK5jBpsFZmTvHz',
#    'id': '13kHQp4zyK5jBpsFZmTvHz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273bdbc6077205378b6271af4bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02bdbc6077205378b6271af4bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851bdbc6077205378b6271af4bf',
#      'width': 64}],
#    'name': 'DISHARMONY : FIND OUT',
#    'release_date': '2022-01-03',
#    'release_date_precision': 'day',
#    'total_tracks': 6,
#    'type': 'album',
#    'uri': 'spotify:album:13kHQp4zyK5jBpsFZmTvHz'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3JjvsPeGMbDJqsphe2z8xU'},
#     'href': 'https://api.spotify.com/v1/artists/3JjvsPeGMbDJqsphe2z8xU',
#     'id': '3JjvsPeGMbDJqsphe2z8xU',
#     'name': 'P1Harmony',
#     'type': 'artist',
#     'uri': 'spotify:artist:3JjvsPeGMbDJqsphe2z8xU'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 192093,
#   'explicit': False,
#   'external_ids': {'isrc': 'KRA382164336'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0aW4RWeGekBfU2NhREc5kL'},
#   'href': 'https://api.spotify.com/v1/tracks/0aW4RWeGekBfU2NhREc5kL',
#   'id': '0aW4RWeGekBfU2NhREc5kL',
#   'is_local': False,
#   'name': 'Do It Like This',
#   'popularity': 63,
#   'preview_url': 'https://p.scdn.co/mp3-preview/60b1eb76605b40316b3fd0559c11c37fbbd0d339?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0aW4RWeGekBfU2NhREc5kL'},
#  {'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uNxlIP5lzPFf0BHuELOuX'},
#      'href': 'https://api.spotify.com/v1/artists/6uNxlIP5lzPFf0BHuELOuX',
#      'id': '6uNxlIP5lzPFf0BHuELOuX',
#      'name': 'GOT the beat',
#      'type': 'artist',
#      'uri': 'spotify:artist:6uNxlIP5lzPFf0BHuELOuX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2Gxd1fr4RFHVNx6IxGr9I7'},
#    'href': 'https://api.spotify.com/v1/albums/2Gxd1fr4RFHVNx6IxGr9I7',
#    'id': '2Gxd1fr4RFHVNx6IxGr9I7',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738a595377408ac1b91186223b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028a595377408ac1b91186223b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518a595377408ac1b91186223b',
#      'width': 64}],
#    'name': 'Stamp On It - The 1st Mini Album',
#    'release_date': '2023-01-16',
#    'release_date_precision': 'day',
#    'total_tracks': 6,
#    'type': 'album',
#    'uri': 'spotify:album:2Gxd1fr4RFHVNx6IxGr9I7'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uNxlIP5lzPFf0BHuELOuX'},
#     'href': 'https://api.spotify.com/v1/artists/6uNxlIP5lzPFf0BHuELOuX',
#     'id': '6uNxlIP5lzPFf0BHuELOuX',
#     'name': 'GOT the beat',
#     'type': 'artist',
#     'uri': 'spotify:artist:6uNxlIP5lzPFf0BHuELOuX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 247493,
#   'explicit': False,
#   'external_ids': {'isrc': 'KRA302300007'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/08pPhcvPmphUEx3pEBZwGZ'},
#   'href': 'https://api.spotify.com/v1/tracks/08pPhcvPmphUEx3pEBZwGZ',
#   'id': '08pPhcvPmphUEx3pEBZwGZ',
#   'is_local': False,
#   'name': 'Alter Ego',
#   'popularity': 52,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ab49b37b664aa95150f69e2fe4d061f68c1bf71b?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:08pPhcvPmphUEx3pEBZwGZ'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SpbR6yFEvexJuaBpgAU5p'},
#      'href': 'https://api.spotify.com/v1/artists/4SpbR6yFEvexJuaBpgAU5p',
#      'id': '4SpbR6yFEvexJuaBpgAU5p',
#      'name': 'LE SSERAFIM',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SpbR6yFEvexJuaBpgAU5p'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4Oz7K9DRwwGMN49i4NbVDT'},
#    'href': 'https://api.spotify.com/v1/albums/4Oz7K9DRwwGMN49i4NbVDT',
#    'id': '4Oz7K9DRwwGMN49i4NbVDT',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d71fd77b89d08bc1bda219c7',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d71fd77b89d08bc1bda219c7',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d71fd77b89d08bc1bda219c7',
#      'width': 64}],
#    'name': 'UNFORGIVEN',
#    'release_date': '2023-05-01',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:4Oz7K9DRwwGMN49i4NbVDT'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SpbR6yFEvexJuaBpgAU5p'},
#     'href': 'https://api.spotify.com/v1/artists/4SpbR6yFEvexJuaBpgAU5p',
#     'id': '4SpbR6yFEvexJuaBpgAU5p',
#     'name': 'LE SSERAFIM',
#     'type': 'artist',
#     'uri': 'spotify:artist:4SpbR6yFEvexJuaBpgAU5p'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 184823,
#   'explicit': False,
#   'external_ids': {'isrc': 'USA2P2310664'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6DSGb5CmwHX4pvclq8HUU1'},
#   'href': 'https://api.spotify.com/v1/tracks/6DSGb5CmwHX4pvclq8HUU1',
#   'id': '6DSGb5CmwHX4pvclq8HUU1',
#   'is_local': False,
#   'name': 'No-Return (Into the unknown)',
#   'popularity': 72,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3c1233266f42392ec4b863fe462d105bf53fbb2a?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:6DSGb5CmwHX4pvclq8HUU1'},
#  {'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01XYiBYaoMJcNhPokrg0l0'},
#      'href': 'https://api.spotify.com/v1/artists/01XYiBYaoMJcNhPokrg0l0',
#      'id': '01XYiBYaoMJcNhPokrg0l0',
#      'name': 'STAYC',
#      'type': 'artist',
#      'uri': 'spotify:artist:01XYiBYaoMJcNhPokrg0l0'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/04EniWu488MF6louRYafKJ'},
#    'href': 'https://api.spotify.com/v1/albums/04EniWu488MF6louRYafKJ',
#    'id': '04EniWu488MF6louRYafKJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c76a0146e4c1804f22cab995',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c76a0146e4c1804f22cab995',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c76a0146e4c1804f22cab995',
#      'width': 64}],
#    'name': 'WE NEED LOVE',
#    'release_date': '2022-07-19',
#    'release_date_precision': 'day',
#    'total_tracks': 4,
#    'type': 'album',
#    'uri': 'spotify:album:04EniWu488MF6louRYafKJ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01XYiBYaoMJcNhPokrg0l0'},
#     'href': 'https://api.spotify.com/v1/artists/01XYiBYaoMJcNhPokrg0l0',
#     'id': '01XYiBYaoMJcNhPokrg0l0',
#     'name': 'STAYC',
#     'type': 'artist',
#     'uri': 'spotify:artist:01XYiBYaoMJcNhPokrg0l0'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 180000,
#   'explicit': False,
#   'external_ids': {'isrc': 'KRA382206236'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/56s2s5e8WuBsWVKnmz6J9L'},
#   'href': 'https://api.spotify.com/v1/tracks/56s2s5e8WuBsWVKnmz6J9L',
#   'id': '56s2s5e8WuBsWVKnmz6J9L',
#   'is_local': False,
#   'name': 'BEAUTIFUL MONSTER',
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c185b149d3094136b006362b257f5218ff50900f?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:56s2s5e8WuBsWVKnmz6J9L'},
#  {'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0DRiXmEOc6dJ6Rug3xi4HZ'},
#      'href': 'https://api.spotify.com/v1/artists/0DRiXmEOc6dJ6Rug3xi4HZ',
#      'id': '0DRiXmEOc6dJ6Rug3xi4HZ',
#      'name': 'THE NEW SIX',
#      'type': 'artist',
#      'uri': 'spotify:artist:0DRiXmEOc6dJ6Rug3xi4HZ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3k4xr3Bn9NfyX7O1nlK7Mg'},
#    'href': 'https://api.spotify.com/v1/albums/3k4xr3Bn9NfyX7O1nlK7Mg',
#    'id': '3k4xr3Bn9NfyX7O1nlK7Mg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273eefa62737df26882a4e51b0f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02eefa62737df26882a4e51b0f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851eefa62737df26882a4e51b0f',
#      'width': 64}],
#    'name': 'BOYHOOD',
#    'release_date': '2023-06-07',
#    'release_date_precision': 'day',
#    'total_tracks': 6,
#    'type': 'album',
#    'uri': 'spotify:album:3k4xr3Bn9NfyX7O1nlK7Mg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0DRiXmEOc6dJ6Rug3xi4HZ'},
#     'href': 'https://api.spotify.com/v1/artists/0DRiXmEOc6dJ6Rug3xi4HZ',
#     'id': '0DRiXmEOc6dJ6Rug3xi4HZ',
#     'name': 'THE NEW SIX',
#     'type': 'artist',
#     'uri': 'spotify:artist:0DRiXmEOc6dJ6Rug3xi4HZ'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
# ...
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0XJXxqADyzn0ed4QbTvsBD'},
#    'href': 'https://api.spotify.com/v1/albums/0XJXxqADyzn0ed4QbTvsBD',
#    'id': '0XJXxqADyzn0ed4QbTvsBD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27395876f245faea11f5824f807',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0295876f245faea11f5824f807',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485195876f245faea11f5824f807',
#      'width': 64}],
#    'name': 'PINK YOUR MOMENT',
#    'release_date': '2023-04-26',
#    'release_date_precision': 'day',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:0XJXxqADyzn0ed4QbTvsBD'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2pHkxVNynHBwQHhGaoBIXX'},
#     'href': 'https://api.spotify.com/v1/artists/2pHkxVNynHBwQHhGaoBIXX',
#     'id': '2pHkxVNynHBwQHhGaoBIXX',
#     'name': 'MINNIE',
#     'type': 'artist',
#     'uri': 'spotify:artist:2pHkxVNynHBwQHhGaoBIXX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 177055,
#   'explicit': False,
#   'external_ids': {'isrc': 'KRF222300021'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0Z4g9s48umnsfDYGKj7jOT'},
#   'href': 'https://api.spotify.com/v1/tracks/0Z4g9s48umnsfDYGKj7jOT',
#   'id': '0Z4g9s48umnsfDYGKj7jOT',
#   'is_local': False,
#   'name': 'PINK YOUR MOMENT',
#   'popularity': 53,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8820a7c1ebf9bad4348707b5d57ea7c07d95f246?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0Z4g9s48umnsfDYGKj7jOT'},
#  {'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xfxRiKxoHl5tI0MKyvqV7'},
#      'href': 'https://api.spotify.com/v1/artists/2xfxRiKxoHl5tI0MKyvqV7',
#      'id': '2xfxRiKxoHl5tI0MKyvqV7',
#      'name': '&TEAM',
#      'type': 'artist',
#      'uri': 'spotify:artist:2xfxRiKxoHl5tI0MKyvqV7'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0ouqxqCo93ccmKOXhMz3RC'},
#    'href': 'https://api.spotify.com/v1/albums/0ouqxqCo93ccmKOXhMz3RC',
#    'id': '0ouqxqCo93ccmKOXhMz3RC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27359121048e3ee4e355bb22171',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0259121048e3ee4e355bb22171',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485159121048e3ee4e355bb22171',
#      'width': 64}],
#    'name': 'First Howling : WE',
#    'release_date': '2023-06-13',
#    'release_date_precision': 'day',
#    'total_tracks': 6,
#    'type': 'album',
#    'uri': 'spotify:album:0ouqxqCo93ccmKOXhMz3RC'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xfxRiKxoHl5tI0MKyvqV7'},
#     'href': 'https://api.spotify.com/v1/artists/2xfxRiKxoHl5tI0MKyvqV7',
#     'id': '2xfxRiKxoHl5tI0MKyvqV7',
#     'name': '&TEAM',
#     'type': 'artist',
#     'uri': 'spotify:artist:2xfxRiKxoHl5tI0MKyvqV7'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 188040,
#   'explicit': False,
#   'external_ids': {'isrc': 'JPPO02301649'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3zm2vstYNDymgIelgK8QOk'},
#   'href': 'https://api.spotify.com/v1/tracks/3zm2vstYNDymgIelgK8QOk',
#   'id': '3zm2vstYNDymgIelgK8QOk',
#   'is_local': False,
#   'name': 'FIREWORK - Korean ver.',
#   'popularity': 60,
#   'preview_url': None,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:3zm2vstYNDymgIelgK8QOk'},
#  {'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HvZYsbFfjnjFrWF950C9d'},
#      'href': 'https://api.spotify.com/v1/artists/6HvZYsbFfjnjFrWF950C9d',
#      'id': '6HvZYsbFfjnjFrWF950C9d',
#      'name': 'NewJeans',
#      'type': 'artist',
#      'uri': 'spotify:artist:6HvZYsbFfjnjFrWF950C9d'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1HMLpmZAnNyl9pxvOnTovV'},
#    'href': 'https://api.spotify.com/v1/albums/1HMLpmZAnNyl9pxvOnTovV',
#    'id': '1HMLpmZAnNyl9pxvOnTovV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739d28fd01859073a3ae6ea209',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029d28fd01859073a3ae6ea209',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519d28fd01859073a3ae6ea209',
#      'width': 64}],
#    'name': "NewJeans 1st EP 'New Jeans'",
#    'release_date': '2022-08-01',
#    'release_date_precision': 'day',
#    'total_tracks': 4,
#    'type': 'album',
#    'uri': 'spotify:album:1HMLpmZAnNyl9pxvOnTovV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HvZYsbFfjnjFrWF950C9d'},
#     'href': 'https://api.spotify.com/v1/artists/6HvZYsbFfjnjFrWF950C9d',
#     'id': '6HvZYsbFfjnjFrWF950C9d',
#     'name': 'NewJeans',
#     'type': 'artist',
#     'uri': 'spotify:artist:6HvZYsbFfjnjFrWF950C9d'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 235562,
#   'explicit': False,
#   'external_ids': {'isrc': 'USA2P2230223'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2DwUdMJ5uxv20EhAildreg'},
#   'href': 'https://api.spotify.com/v1/tracks/2DwUdMJ5uxv20EhAildreg',
#   'id': '2DwUdMJ5uxv20EhAildreg',
#   'is_local': False,
#   'name': 'Cookie',
#   'popularity': 81,
#   'preview_url': 'https://p.scdn.co/mp3-preview/d059b8ea163242692099c452cbed3de596c2e624?cid=a44e325b50154f278abc68994957c7ad',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:2DwUdMJ5uxv20EhAildreg'}]

# %% [markdown]
# ## AUDIO FEATURE VS POPULARITY

# %%
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']

for feature in features:
    # Scatter plot of feature vs. popularity for each generation
    
    # Second Generation
    plt.scatter(secondgen2[feature], secondgen2['Popularity'], color='red', alpha=0.5, label='Second Gen')
    
    # Third Generation
    plt.scatter(thirdgen2[feature], thirdgen2['Popularity'], color='blue', alpha=0.5, label='Third Gen')
    
    # Fourth Generation
    plt.scatter(fourthgen2[feature], fourthgen2['Popularity'], color='green', alpha=0.5, label='Fourth Gen')
    
    # Plot settings
    plt.title(f'{feature.capitalize()} vs. Popularity')
    plt.xlabel(feature.capitalize())
    plt.ylabel('Popularity')
    plt.legend()
    plt.show()

# %% [markdown]
# no clear trend in popularity relative to audio features
#
# clearly second generation is less popular, does not have to do with audio features, just personal preference and popularity of kpop groups themselves

# %% [markdown]
# ## Deeper Analysis

# %%
# Only tempo
features = ['tempo']

# Calculate the mean of audio features for each generation
mean_secondgen = secondgen2[features].mean()
mean_thirdgen = thirdgen2[features].mean()
mean_fourthgen = fourthgen2[features].mean()

# Create a DataFrame for mean values
mean_features = pd.DataFrame({'Second Generation': mean_secondgen, 'Third Generation': mean_thirdgen, 'Fourth Generation': mean_fourthgen})

# Plot the mean of audio features by generation
mean_features.plot(kind='bar', figsize=(10, 6))
plt.title('Mean Audio Features by Generation (Excluding Tempo)')
plt.xlabel('Audio Feature')
plt.ylabel('Mean Value')
plt.xticks(rotation=0)
plt.legend(title='Generation')
plt.show()

# %%
# Exclude 'tempo' feature 
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence']

# Calculate the mean of audio features for each generation
mean_secondgen = secondgen2[features].mean()
mean_thirdgen = thirdgen2[features].mean()
mean_fourthgen = fourthgen2[features].mean()

# Create a DataFrame for mean values
mean_features = pd.DataFrame({'Second Generation': mean_secondgen, 'Third Generation': mean_thirdgen, 'Fourth Generation': mean_fourthgen})

# Plot the mean of audio features by generation
mean_features.plot(kind='bar', figsize=(10, 6))
plt.title('Mean Audio Features by Generation (Excluding Tempo)')
plt.xlabel('Audio Feature')
plt.ylabel('Mean Value')
plt.xticks(rotation=0)
plt.legend(title='Generation')
plt.show()

# %%
# Calculate statistics for track duration and tempo
avg_track_duration = secondgen2['duration_ms'].mean() / 1000  
avg_tempo = secondgen2['tempo'].mean()

print('Average Track Duration:', avg_track_duration, 'seconds')
print('Average Tempo:', avg_tempo, 'BPM')
# Out:
# Average Track Duration: 218.132175 seconds
# Average Tempo: 117.96945 BPM

# %%
# Calculate statistics for track duration and tempo
avg_track_duration = thirdgen2['duration_ms'].mean() / 1000  
avg_tempo = thirdgen2['tempo'].mean()

print('Average Track Duration:', avg_track_duration, 'seconds')
print('Average Tempo:', avg_tempo, 'BPM')
# Out:
# Average Track Duration: 198.83722500000002 seconds
# Average Tempo: 118.47765 BPM

# %%
# Calculate statistics for track duration and tempo
avg_track_duration = fourthgen2['duration_ms'].mean() / 1000  
avg_tempo = fourthgen2['tempo'].mean()

print('Average Track Duration:', avg_track_duration, 'seconds')
print('Average Tempo:', avg_tempo, 'BPM')
# Out:
# Average Track Duration: 186.647125 seconds
# Average Tempo: 130.60985 BPM
